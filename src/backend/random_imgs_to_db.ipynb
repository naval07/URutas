# %%
import pandas as pd
import random

# %%
# importación del dataset
cursos = pd.read_csv('Final_Cursos_normalizados.csv')
cursos.head(10)
# Out:
#                                               Título  \
# 0                    Diseno y Analisis de Algoritmos
# 1                                   Teoria de grafos
# 2                  Fundamentos de Sistemas Digitales
# 3                                          Calculo 3
# 4              Procesamiento  de Senales  e Imagenes
# 5                             Redes  de Computadores
# 6                           Energia y Medio Ambiente
# 7                                         Simulacion
# 8             Logica para ciencias de la computacion
# 9  Seguridad  en el Ciclo  de Desarrollo  de Soft...
#
#                               Unidad Académica Área temática  \
# 0  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
# 1  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
# 2  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA           ING
# 3  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
# 4  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
# 5  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
# 6  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA           ING
# 7  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA           ING
# 8  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
# 9  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
#
#                          Propósito general del curso  \
# 0  Aunque la capacidad de procesamiento y almacen...
# 1  La teoria de grafos es la formalizacion y pres...
# 2  Esta materia introduce al estudiante en las ba...
# 3  Este curso tiene como proposito acercar a los ...
# 4  Este curso presentara una introduccion al anal...
# 5  Este es un primer curso en redes de computador...
# 6  El curso de Energia y Medio Ambiente es de car...
# 7  Esta asignatura introduce a la teoria de colas...
# 8  En este curso examinaremos en gran detalle uno...
# 9  En la actualidad se presenta un sin numero de ...
#
#   Resultados de aprendizaje esperados Nivel Curso individual o programa  \
# 0                                   X   NaN                    Programa
# 1                                   X   NaN                    Programa
# 2                                   X   NaN                    Programa
# 3                                   X   NaN                    Programa
# 4                                   X   NaN                    Programa
# 5                                   X   NaN                    Programa
# 6                                   X   NaN                    Programa
# 7                                   X   NaN                    Programa
# 8                                   X   NaN                    Programa
# 9                                   X   NaN                    Programa
#
#                                       proposito_norm
# 0  aunque capacidad procesamiento almacenamiento ...
# 1  teoria grafos formalizacion presentacion matem...
# 2  materia introduce estudiante bases hardware or...
# 3  curso proposito acercar estudiantes conceptos ...
# 4  curso presentara introduccion analisis espectr...
# 5  primer curso redes computadores introduce estu...
# 6  curso energia medio ambiente caracter teorico ...
# 7  asignatura introduce teoria colas teoria linea...
# 8  curso examinaremos gran detalle sistemas forma...
# 9  actualidad presenta numero incidentes informat...

# %%
# Creación de la lista que contiene imágenes aleatorias
num_cursos = cursos.shape[0]
lista_imgs = []

for i in range(num_cursos):
    numero_random = random.randrange(1,11)
    ruta = f'/fondoCartas/img{numero_random}.jpg'
    lista_imgs.append(ruta)

# %%
cursos['ruta_img'] = lista_imgs

# %%
cursos.head(5)
# Out:
#                                   Título  \
# 0        Diseno y Analisis de Algoritmos
# 1                       Teoria de grafos
# 2      Fundamentos de Sistemas Digitales
# 3                              Calculo 3
# 4  Procesamiento  de Senales  e Imagenes
#
#                               Unidad Académica Área temática  \
# 0  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
# 1  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
# 2  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA           ING
# 3  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
# 4  ESCUELA DE INGENIERIA CIENCIAS Y TECNOLOGIA          MACC
#
#                          Propósito general del curso  \
# 0  Aunque la capacidad de procesamiento y almacen...
# 1  La teoria de grafos es la formalizacion y pres...
# 2  Esta materia introduce al estudiante en las ba...
# 3  Este curso tiene como proposito acercar a los ...
# 4  Este curso presentara una introduccion al anal...
#
#   Resultados de aprendizaje esperados Nivel Curso individual o programa  \
# 0                                   X   NaN                    Programa
# 1                                   X   NaN                    Programa
# 2                                   X   NaN                    Programa
# 3                                   X   NaN                    Programa
# 4                                   X   NaN                    Programa
#
#                                       proposito_norm               ruta_img
# 0  aunque capacidad procesamiento almacenamiento ...  /fondoCartas/img8.jpg
# 1  teoria grafos formalizacion presentacion matem...  /fondoCartas/img2.jpg
# 2  materia introduce estudiante bases hardware or...  /fondoCartas/img3.jpg
# 3  curso proposito acercar estudiantes conceptos ...  /fondoCartas/img4.jpg
# 4  curso presentara introduccion analisis espectr...  /fondoCartas/img8.jpg

# %%
# Guardado de nueva db
cursos.to_csv('Final_Cursos_normalizados_imgs.csv')
